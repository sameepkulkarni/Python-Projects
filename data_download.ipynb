# %%
import requests
import pandas as pd

api_key = "olC7b3Iae2DXrAAAvaTBnGapqSzpMjCW"
symbol = "C:XAUUSD"  # Gold Futures on COMEX
interval = "minute"
from_date = "2023-05-01"
to_date = "2025-06-02"

# Initial URL
base_url = f"https://api.polygon.io/v2/aggs/ticker/{symbol}/range/5/{interval}/{from_date}/{to_date}?adjusted=true&sort=asc&limit=50000&apiKey={api_key}"

all_data = []

while base_url:
    response = requests.get(base_url)
    if response.status_code != 200:
        print("Request failed:", response.status_code, response.text)
        break

    json_data = response.json()

    # Check if 'results' exist
    if 'results' in json_data:
        all_data.extend(json_data['results'])

    # Get next page URL if available
    base_url = json_data.get('next_url')
    if base_url:
        base_url += f"&apiKey={api_key}"  # Ensure API key is appended

# Convert to DataFrame
if all_data:
    df = pd.DataFrame(all_data)
    df['timestamp'] = pd.to_datetime(df['t'], unit='ms')
    print(df.head())
    df.to_csv('gold_data_5_minutes.csv', index=False)
else:
    print("No data returned.")
# Out:
# Request failed: 429 {"status":"ERROR","request_id":"a5b147df5237fafa0b73f39afa383eef","error":"You've exceeded the maximum requests per minute, please wait or upgrade your subscription to continue. https://polygon.io/pricing"}
#     v         vw        o        c        h        l              t   n  \
# 0  14  1944.5221  1944.36  1944.88  1944.93  1944.00  1686182400000  14
# 1  13  1945.0800  1944.61  1945.26  1945.41  1944.61  1686182700000  13
# 2  13  1945.0238  1945.41  1945.29  1945.41  1944.88  1686183000000  13
# 3  13  1945.3677  1945.00  1945.37  1945.61  1945.00  1686183300000  13
# 4  13  1945.2877  1945.20  1945.22  1945.35  1945.20  1686183600000  13
#
#             timestamp
# 0 2023-06-08 00:00:00
# 1 2023-06-08 00:05:00
# 2 2023-06-08 00:10:00
# 3 2023-06-08 00:15:00
# 4 2023-06-08 00:20:00

# %%
import pandas as pd
gold_5min = pd.read_csv('gold_data_5_minutes.csv', index_col='timestamp')

# %%
gold_5min.tail()
# Out:
#                       v         vw        o        c        h        l  \
# timestamp
# 2024-02-26 15:45:00  14  2027.8764  2027.10  2028.09  2028.27  2027.10
# 2024-02-26 15:50:00  13  2028.7339  2028.07  2029.94  2029.94  2028.07
# 2024-02-26 15:55:00  12  2029.0342  2028.51  2029.12  2029.22  2028.51
# 2024-02-26 16:00:00  13  2028.7954  2029.31  2028.08  2029.31  2028.08
# 2024-02-26 16:05:00  13  2028.1315  2028.33  2027.59  2028.51  2027.59
#
#                                  t   n
# timestamp
# 2024-02-26 15:45:00  1708962300000  14
# 2024-02-26 15:50:00  1708962600000  13
# 2024-02-26 15:55:00  1708962900000  12
# 2024-02-26 16:00:00  1708963200000  13
# 2024-02-26 16:05:00  1708963500000  13

# %%
len(gold_5min)
# Out:
# 50342

# %%
import matplotlib.pyplot as plt
gold_5min_short = gold_5min
plt.figure(figsize=(12, 6))
plt.plot(gold_5min_short.index, gold_5min_short['c'], label='Price', color='blue', alpha=0.6, linewidth=1)
plt.title('Gold Price (5-Minute Intervals)')
plt.xlabel('Date and Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True, alpha=0.5)
# Out:
# Error in callback <function _draw_all_if_interactive at 0x000001FA042F4400> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\A\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:279, in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#
# File c:\Users\A\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# ...
