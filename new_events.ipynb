# %%
import requests
import pandas as pd

API_KEY = '05ecc7bc1ba34af:cpmhxsjqhr47dgl'
url = f"https://api.tradingeconomics.com/calendar?c={API_KEY}&country=united states&start_date=2023-05-01&end_date=2025-07-31"

response = requests.get(url)
print(response.status_code)
print(response.text)  # See what's being returned

data = response.json()
df_2 = pd.DataFrame(data)

# # Filter important columns
# df = df[df['Importance'] == 3]  # 3 = High Impact
# df = df[['Date', 'Country', 'Event', 'Actual', 'Forecast', 'Previous']]
# Out:
# 200
# ...

# %%
# Out:
# 10
